# %%
library("twitteR")
setup_twitter_oauth("", "", "", "")
# Out:
# [1] "Using direct authentication"

# %%
search_query <- "#trump"
tweets <- searchTwitter(search_query, n=20)
head(tweets)
Data_frame <- twListToDF(tweets)
nrow(Data_frame)
# Out:
# [[1]]
# [1] "ameliashallcro2: RT @immigrant4trump: Over 10,000 For President Trump in Melbourne, Florida! Full House! #Maga #Trump https://t.co/9GO6kayRjp"
#
# [[2]]
# [1] "Brenny1097: RT @immigrant4trump: Very True! #Trump #Maga https://t.co/6cq1rsXyBm"
#
# [[3]]
# [1] "DebbiebB15: RT @StopTrump2020: Just more #FakeNews coming out of #Trump's mouth https://t.co/lsyeH8HOKi"
#
# [[4]]
# [1] "opgeoengineeri1: Wow! FULL EVENT President Donald Trump HUUGE Rally in Melbourne, Florida 2/18/17 #Trump Melbourne Speech https://t.co/W9vNXjVnsq"
#
# [[5]]
# [1] "onlymytruths: RT @Gingrich_of_PA: #Saturday Night Live #Trump Just Warming Up #Dixie Cup Salutes https://t.co/Sf0VVXYuTj"
#
# [[6]]
# [1] "realityisagoodt: RT @immigrant4trump: Every time The Media say GOP speaks out against trump, Its these two, #Trump #Maga https://t.co/byTe51Mj9E"
# [1] 20

# %%
TrumpAVClub <- getUser('TrumpAVClub')
TrumpAVClub$getDescription()
# Out:
# [1] "Trump gives nuanced reviews of pop culture and entertainment,in lieu of attending intelligence briefings.  SAD!"

# %%
TrumpAVClub$getFollowersCount()
# Out:
# [1] 49

# %%
TrumpAVClub$getFriends(n=5)
# Out:
# $`828388878826500096`
# [1] "AltWHKitchen"
#
# $`796618934434889728`
# [1] "ScottLee1967"
#
# $`15359578`
# [1] "christinawilkie"
#
# $`18602100`
# [1] "PhilippeReines"
#
# $`14230524`
# [1] "ladygaga"

# %%
TrumpAVClub$getFavorites(n=5)
# Out:
# [[1]]
# [1] "YourManagemenH: RT threetails: Here now with what may be video of the incident #LastNightInSweden https://t.co/BsONJ3V1xX"
#
# [[2]]
# [1] "pourmecoffee: Ha.\n\n\"Diner overwhelmed with customers after it is accidentally awarded a Michelin star\" https://t.co/IGlbIeRbtK https://t.co/G4rBubfr9Z"
#
# [[3]]
# [1] "pamboy712: @AltWHKitchen @alt_labor @kbeecee I will send a virtual toaster to any Alt-wedding https://t.co/5nv64OTwQK"
#
# [[4]]
# [1] "LastNiteNSweden: Last night, we watched our usual TV. Today, we are REALLY looking forward to Saturday Night Live. #LastNightInSweden #SNL"
#
# [[5]]
# [1] "annebethsedore: #LastNightInSweden parents stayed home for over a year for parental leave.  They did not go to a madman's rally 1 mo into failed presidency"

# %%
library(RSQLite)

# %%
con1 <- dbConnect(SQLite(), dbname="/Users/Amardeep/Documents/Semester_2/Dic/Test")

# %%
dbWriteTable(con1, "Test_DB", Data_frame, append= TRUE)
dbReadTable(con1, "Test_DB")
# Out:
# [1] TRUE
#    text
# 1  #Hollande is a moron, no one will miss him. #AfD #UKIP #Trump #LegaNord #FP<U+00D6> #EU #Marine2017 #Trump https://t.co/Rplp5kWhhB
# 2  #Trump tweets #Lincoln quote:\n"Everything is a dildo,\nunless you're a bitch."
# 3  RT @bocavista2016: Dear #FakeNews\n\nWE'RE DONE W/ YOU\n\nWE want #Trump\n\n<ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8>#MAGA <ed><U+00A0><U+00BC><ed><U+00B7><U+00BA><ed><U+00A0><U+00BC><ed><U+00B7><U+00B8>\n\nhttps://t.co/Utt3my5gw1\nhttps://t.co/sKeaLx3rvF\n#TrumpRal<U+2026>
# 4  RT @buddystone: <ed><U+00A0><U+00BC><ed><U+00B7><U+00B8><ed><U+00A0><U+00BC><ed><U+00B7><U+00AA>#Trump's tiny #Swedish meatballs were massacred #lastnightinSweden <ed><U+00A0><U+00BD><ed><U+00B9><U+0084> https://t.co/f8QDlsJdpG
# 5  RT @immigrant4trump: Amazing Courageous @Joy_Villa Hits The Bill Board Top 10! "Overwhelming Support" #Maga #Trump https://t.co/5gVuO8BBaR
# ...

# %%
Trump_time <- userTimeline('TrumpAVClub')
Trump_time[1:5]
# Out:
# [[1]]
# [1] "TrumpAVClub: @WestWingReport SAD!"
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL

# %%
avail_trends = availableTrendLocations()
head(avail_trends)
# Out:
#   name      country woeid
# 1 Worldwide         1
# 2 Winnipeg  Canada  2972
# 3 Ottawa    Canada  3369
# 4 Quebec    Canada  3444
# 5 Montreal  Canada  3534
# 6 Toronto   Canada  4118

# %%
close_trends = closestTrendLocations(24, -79.1)
head(close_trends)
# Out:
#   name  country       woeid
# 1 Miami United States 2450022

# %%
trends = getTrends(close_trends$woeid)
head(trends)
# Out:
#   name           url
# 1 #Miami         http://twitter.com/search?q=%23Miami
# 2 Venezuela      http://twitter.com/search?q=Venezuela
# 3 #HurtBae       http://twitter.com/search?q=%23HurtBae
# 4 #PLLMemoryLane http://twitter.com/search?q=%23PLLMemoryLane
# 5 #SagerStrong   http://twitter.com/search?q=%23SagerStrong
# 6 Eric Gordon    http://twitter.com/search?q=%22Eric+Gordon%22
#   query             woeid
# 1 %23Miami          2450022
# 2 Venezuela         2450022
# 3 %23HurtBae        2450022
# 4 %23PLLMemoryLane  2450022
# 5 %23SagerStrong    2450022
# 6 %22Eric+Gordon%22 2450022

# %%
r_tweets <- searchTwitter("#Trump", n=300)

sources <- sapply(r_tweets, function(x) x$getStatusSource())

sources <- gsub("</a>", "", sources)

sources <- strsplit(sources, ">")

sources <- sapply(sources, function(x) ifelse(length(x) > 1, x[2], x[1]))

source_table = table(sources)

pie(source_table[source_table > 10])
# Out:
# plot without title

# %% [markdown]
# Refrences :
# https://docs.google.com/viewer?url=http%3A%2F%2Fgeoffjentry.hexdump.org%2FtwitteR.pdf
