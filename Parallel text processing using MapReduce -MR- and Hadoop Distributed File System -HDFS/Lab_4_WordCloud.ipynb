# %%
# install.packages("wordcloud")
# install.packages("RColorBrewer")
library("tm")
library("wordcloud")
library("RColorBrewer")

# %%
filePath <- "/Users/Amardeep/Documents/Semester_2/Dic/Lab_4/tweet_output.txt"
# text <- readLines(filePath)

# %%
# docs <- Corpus(VectorSource(text))
# inspect(docs)
# Out:
# <<SimpleCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 0
# Content:  documents: 2294
#
#    [1] a\t1061
#    [2] about\t19
#    [3] absence\t2
#    [4] absolute\t2
#    [5] absolutely\t1
#    [6] accept\t2
#    [7] accuracy\t1
#    [8] achievingmessi\t1
#    [9] acted\t1
#   [10] actual\t1
#   [11] actually\t1
#   [12] added\t44
#   [13] adidas\t1
#   [14] admire\t1
#   [15] admits\t1
#   [16] admitting\t1
#   [17] advantage\t13
#   [18] advantagehave\t2
#   [19] adve\t1
#   [20] advice\t4
#   [21] aelclasico\t3
#   [22] afraid\t2
#   [23] african\t1
#   [24] after\t146
#   [25] again\t18
#   [26] againelclsico\t1
#   [27] against\t36
#   [28] againstelclasico\t3
#   [29] againtotal\t1
#   [30] ahokforbali\t1
#   [31] aicles\t3
#   [32] aint\t1
#   [33] al\t1
#   [34] ales\t1
#   [35] alfredo\t4
#   [36] alien\t4
#   [37] aliens\t1
#   [38] alienwe\t1
#   [39] alive\t1
#   [40] all\t41
#   [41] allowed\t2
#   [42] alltime\t3
#   [43] alone\t2
#   [44] alot\t1
# ...

# %%
myMatrix <- as.matrix(read.table(filePath, sep="\t"))
# head(myMatrix)

d <- data.frame(myMatrix)
head(d)
# docs <- tm_map(docs, removeNumbers)
# dtm <- TermDocumentMatrix(docs)
# m <- as.matrix(dtm)
# v <- sort(rowSums(m),decreasing=TRUE)
# d <- data.frame(word = names(v),freq=v)
# head(d, 10)
# Out:
#   V1         V2
# 1 a          1061
# 2 about        19
# 3 absence       2
# 4 absolute      2
# 5 absolutely    1
# 6 accept        2

# %%
set.seed(1234)
wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), min.freq = 20,
          max.words=200, random.order=FALSE, rot.per=0.35, 
          colors=brewer.pal(8, "Dark2"))
# Out:
# Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# “happens could not be fit on page. It will not be plotted.”Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# “ligamessi could not be fit on page. It will not be plotted.”Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# “settle could not be fit on page. It will not be plotted.”Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# “reaction could not be fit on page. It will not be plotted.”Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# “santiago could not be fit on page. It will not be plotted.”Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# “hus could not be fit on page. It will not be plotted.”Warning message in wordcloud(words = as.character(d$V1), freq = as.numeric(d$V2), :
# ...
